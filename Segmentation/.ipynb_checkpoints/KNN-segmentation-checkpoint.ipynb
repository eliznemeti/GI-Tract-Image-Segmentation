# %%
import pandas as pd
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import os
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
# Set a random seed for reproducibility
np.random.seed(93)

# %%
# Load the CSV file
csv_path = '/Users/elizabethnemeti/Desktop/masks-dataset/train.csv'
df = pd.read_csv(csv_path)

# Base directories for images and masks
images_base_dir = '/Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train'
masks_base_dir = '/Users/elizabethnemeti/Desktop/masks-dataset/png/uw-madison-gi-tract-image-segmentation/train'

# %%
# Function to check if both image and mask are valid
def is_valid_image_mask_pair(image_path, mask_path):
    if not os.path.exists(image_path) or not os.path.exists(mask_path):
        return False
    
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(mask_path)
    
    if image is None or mask is None:
        return False

    combined_mask = np.zeros(mask.shape[:2], dtype=np.uint8)
    combined_mask[mask[:, :, 0] > 0] = 1  # Large bowel
    combined_mask[mask[:, :, 1] > 0] = 2  # Small bowel
    combined_mask[mask[:, :, 2] > 0] = 3  # Stomach

    # Check if all masks have at least one positive pixel
    if not (np.any(combined_mask == 1) and np.any(combined_mask == 2) and np.any(combined_mask == 3)):
        return False

    return True

# Collect images and masks with a limit
print("Collecting valid image-mask pairs...")
max_images = 2000
valid_count = 0
images = []
masks = []

for index, row in df.iterrows():
    if valid_count >= max_images:
        break
    
    image_relative_path = os.path.relpath(row['image_path'], '/kaggle/input/uw-madison-gi-tract-image-segmentation/train')
    image_path = os.path.join(images_base_dir, image_relative_path)
    mask_relative_path = os.path.relpath(row['mask_path'], '/kaggle/input/uwmgi-mask-dataset/png/uw-madison-gi-tract-image-segmentation/train')
    mask_path = os.path.join(masks_base_dir, mask_relative_path)
    
    if is_valid_image_mask_pair(image_path, mask_path):
        valid_count += 1
        images.append(image_path)
        masks.append(mask_path)
        print(f"Processed {valid_count} valid pairs so far...")

print(f"Total valid image-mask pairs collected: {valid_count}")
# Out:
# Collecting valid image-mask pairs...
# Processed 1 valid pairs so far...
# Processed 2 valid pairs so far...
# Processed 3 valid pairs so far...
# Processed 4 valid pairs so far...
# Processed 5 valid pairs so far...
# Processed 6 valid pairs so far...
# Processed 7 valid pairs so far...
# Processed 8 valid pairs so far...
# Processed 9 valid pairs so far...
# Processed 10 valid pairs so far...
# Processed 11 valid pairs so far...
# Processed 12 valid pairs so far...
# Processed 13 valid pairs so far...
# Processed 14 valid pairs so far...
# Processed 15 valid pairs so far...
# Processed 16 valid pairs so far...
# Processed 17 valid pairs so far...
# Processed 18 valid pairs so far...
# Processed 19 valid pairs so far...
# Processed 20 valid pairs so far...
# Processed 21 valid pairs so far...
# Processed 22 valid pairs so far...
# Processed 23 valid pairs so far...
# Processed 24 valid pairs so far...
# Processed 25 valid pairs so far...
# Processed 26 valid pairs so far...
# Processed 27 valid pairs so far...
# Processed 28 valid pairs so far...
# Processed 29 valid pairs so far...
# Processed 30 valid pairs so far...
# Processed 31 valid pairs so far...
# Processed 32 valid pairs so far...
# Processed 33 valid pairs so far...
# Processed 34 valid pairs so far...
# Processed 35 valid pairs so far...
# Processed 36 valid pairs so far...
# Processed 37 valid pairs so far...
# Processed 38 valid pairs so far...
# Processed 39 valid pairs so far...
# Processed 40 valid pairs so far...
# Processed 41 valid pairs so far...
# Processed 42 valid pairs so far...
# Processed 43 valid pairs so far...
# Processed 44 valid pairs so far...
# Processed 45 valid pairs so far...
# Processed 46 valid pairs so far...
# Processed 47 valid pairs so far...
# Processed 48 valid pairs so far...
# Processed 49 valid pairs so far...
# Processed 50 valid pairs so far...
# Processed 51 valid pairs so far...
# Processed 52 valid pairs so far...
# Processed 53 valid pairs so far...
# Processed 54 valid pairs so far...
# Processed 55 valid pairs so far...
# Processed 56 valid pairs so far...
# Processed 57 valid pairs so far...
# Processed 58 valid pairs so far...
# Processed 59 valid pairs so far...
# Processed 60 valid pairs so far...
# Processed 61 valid pairs so far...
# Processed 62 valid pairs so far...
# Processed 63 valid pairs so far...
# Processed 64 valid pairs so far...
# Processed 65 valid pairs so far...
# Processed 66 valid pairs so far...
# Processed 67 valid pairs so far...
# Processed 68 valid pairs so far...
# Processed 69 valid pairs so far...
# Processed 70 valid pairs so far...
# Processed 71 valid pairs so far...
# Processed 72 valid pairs so far...
# Processed 73 valid pairs so far...
# Processed 74 valid pairs so far...
# Processed 75 valid pairs so far...
# Processed 76 valid pairs so far...
# Processed 77 valid pairs so far...
# Processed 78 valid pairs so far...
# Processed 79 valid pairs so far...
# Processed 80 valid pairs so far...
# Processed 81 valid pairs so far...
# Processed 82 valid pairs so far...
# Processed 83 valid pairs so far...
# Processed 84 valid pairs so far...
# Processed 85 valid pairs so far...
# Processed 86 valid pairs so far...
# Processed 87 valid pairs so far...
# Processed 88 valid pairs so far...
# Processed 89 valid pairs so far...
# Processed 90 valid pairs so far...
# Processed 91 valid pairs so far...
# Processed 92 valid pairs so far...
# Processed 93 valid pairs so far...
# Processed 94 valid pairs so far...
# Processed 95 valid pairs so far...
# Processed 96 valid pairs so far...
# Processed 97 valid pairs so far...
# Processed 98 valid pairs so far...
# Processed 99 valid pairs so far...
# Processed 100 valid pairs so far...
# Processed 101 valid pairs so far...
# Processed 102 valid pairs so far...
# Processed 103 valid pairs so far...
# Processed 104 valid pairs so far...
# Processed 105 valid pairs so far...
# Processed 106 valid pairs so far...
# Processed 107 valid pairs so far...
# Processed 108 valid pairs so far...
# Processed 109 valid pairs so far...
# Processed 110 valid pairs so far...
# Processed 111 valid pairs so far...
# Processed 112 valid pairs so far...
# Processed 113 valid pairs so far...
# Processed 114 valid pairs so far...
# Processed 115 valid pairs so far...
# Processed 116 valid pairs so far...
# Processed 117 valid pairs so far...
# Processed 118 valid pairs so far...
# Processed 119 valid pairs so far...
# Processed 120 valid pairs so far...
# Processed 121 valid pairs so far...
# Processed 122 valid pairs so far...
# Processed 123 valid pairs so far...
# Processed 124 valid pairs so far...
# Processed 125 valid pairs so far...
# Processed 126 valid pairs so far...
# Processed 127 valid pairs so far...
# Processed 128 valid pairs so far...
# Processed 129 valid pairs so far...
# Processed 130 valid pairs so far...
# Processed 131 valid pairs so far...
# Processed 132 valid pairs so far...
# Processed 133 valid pairs so far...
# Processed 134 valid pairs so far...
# Processed 135 valid pairs so far...
# Processed 136 valid pairs so far...
# Processed 137 valid pairs so far...
# Processed 138 valid pairs so far...
# Processed 139 valid pairs so far...
# Processed 140 valid pairs so far...
# Processed 141 valid pairs so far...
# Processed 142 valid pairs so far...
# Processed 143 valid pairs so far...
# Processed 144 valid pairs so far...
# Processed 145 valid pairs so far...
# Processed 146 valid pairs so far...
# Processed 147 valid pairs so far...
# Processed 148 valid pairs so far...
# Processed 149 valid pairs so far...
# Processed 150 valid pairs so far...
# Processed 151 valid pairs so far...
# Processed 152 valid pairs so far...
# Processed 153 valid pairs so far...
# Processed 154 valid pairs so far...
# Processed 155 valid pairs so far...
# Processed 156 valid pairs so far...
# Processed 157 valid pairs so far...
# Processed 158 valid pairs so far...
# Processed 159 valid pairs so far...
# Processed 160 valid pairs so far...
# Processed 161 valid pairs so far...
# Processed 162 valid pairs so far...
# Processed 163 valid pairs so far...
# Processed 164 valid pairs so far...
# Processed 165 valid pairs so far...
# Processed 166 valid pairs so far...
# Processed 167 valid pairs so far...
# Processed 168 valid pairs so far...
# Processed 169 valid pairs so far...
# Processed 170 valid pairs so far...
# Processed 171 valid pairs so far...
# Processed 172 valid pairs so far...
# Processed 173 valid pairs so far...
# Processed 174 valid pairs so far...
# Processed 175 valid pairs so far...
# Processed 176 valid pairs so far...
# Processed 177 valid pairs so far...
# Processed 178 valid pairs so far...
# Processed 179 valid pairs so far...
# Processed 180 valid pairs so far...
# Processed 181 valid pairs so far...
# Processed 182 valid pairs so far...
# Processed 183 valid pairs so far...
# Processed 184 valid pairs so far...
# Processed 185 valid pairs so far...
# Processed 186 valid pairs so far...
# Processed 187 valid pairs so far...
# Processed 188 valid pairs so far...
# Processed 189 valid pairs so far...
# Processed 190 valid pairs so far...
# Processed 191 valid pairs so far...
# Processed 192 valid pairs so far...
# Processed 193 valid pairs so far...
# Processed 194 valid pairs so far...
# Processed 195 valid pairs so far...
# Processed 196 valid pairs so far...
# Processed 197 valid pairs so far...
# Processed 198 valid pairs so far...
# Processed 199 valid pairs so far...
# Processed 200 valid pairs so far...
# Processed 201 valid pairs so far...
# Processed 202 valid pairs so far...
# Processed 203 valid pairs so far...
# Processed 204 valid pairs so far...
# Processed 205 valid pairs so far...
# Processed 206 valid pairs so far...
# Processed 207 valid pairs so far...
# Processed 208 valid pairs so far...
# Processed 209 valid pairs so far...
# Processed 210 valid pairs so far...
# Processed 211 valid pairs so far...
# Processed 212 valid pairs so far...
# Processed 213 valid pairs so far...
# Processed 214 valid pairs so far...
# Processed 215 valid pairs so far...
# Processed 216 valid pairs so far...
# Processed 217 valid pairs so far...
# Processed 218 valid pairs so far...
# Processed 219 valid pairs so far...
# Processed 220 valid pairs so far...
# Processed 221 valid pairs so far...
# Processed 222 valid pairs so far...
# Processed 223 valid pairs so far...
# Processed 224 valid pairs so far...
# Processed 225 valid pairs so far...
# Processed 226 valid pairs so far...
# Processed 227 valid pairs so far...
# Processed 228 valid pairs so far...
# Processed 229 valid pairs so far...
# Processed 230 valid pairs so far...
# Processed 231 valid pairs so far...
# Processed 232 valid pairs so far...
# Processed 233 valid pairs so far...
# Processed 234 valid pairs so far...
# Processed 235 valid pairs so far...
# Processed 236 valid pairs so far...
# Processed 237 valid pairs so far...
# Processed 238 valid pairs so far...
# Processed 239 valid pairs so far...
# Processed 240 valid pairs so far...
# Processed 241 valid pairs so far...
# Processed 242 valid pairs so far...
# Processed 243 valid pairs so far...
# Processed 244 valid pairs so far...
# Processed 245 valid pairs so far...
# Processed 246 valid pairs so far...
# Processed 247 valid pairs so far...
# Processed 248 valid pairs so far...
# Processed 249 valid pairs so far...
# Processed 250 valid pairs so far...
# Processed 251 valid pairs so far...
# Processed 252 valid pairs so far...
# Processed 253 valid pairs so far...
# Processed 254 valid pairs so far...
# Processed 255 valid pairs so far...
# Processed 256 valid pairs so far...
# Processed 257 valid pairs so far...
# Processed 258 valid pairs so far...
# Processed 259 valid pairs so far...
# Processed 260 valid pairs so far...
# Processed 261 valid pairs so far...
# Processed 262 valid pairs so far...
# Processed 263 valid pairs so far...
# Processed 264 valid pairs so far...
# Processed 265 valid pairs so far...
# Processed 266 valid pairs so far...
# Processed 267 valid pairs so far...
# Processed 268 valid pairs so far...
# Processed 269 valid pairs so far...
# Processed 270 valid pairs so far...
# Processed 271 valid pairs so far...
# Processed 272 valid pairs so far...
# Processed 273 valid pairs so far...
# Processed 274 valid pairs so far...
# Processed 275 valid pairs so far...
# Processed 276 valid pairs so far...
# Processed 277 valid pairs so far...
# Processed 278 valid pairs so far...
# Processed 279 valid pairs so far...
# Processed 280 valid pairs so far...
# Processed 281 valid pairs so far...
# Processed 282 valid pairs so far...
# Processed 283 valid pairs so far...
# Processed 284 valid pairs so far...
# Processed 285 valid pairs so far...
# Processed 286 valid pairs so far...
# Processed 287 valid pairs so far...
# Processed 288 valid pairs so far...
# Processed 289 valid pairs so far...
# Processed 290 valid pairs so far...
# Processed 291 valid pairs so far...
# Processed 292 valid pairs so far...
# Processed 293 valid pairs so far...
# Processed 294 valid pairs so far...
# Processed 295 valid pairs so far...
# Processed 296 valid pairs so far...
# Processed 297 valid pairs so far...
# Processed 298 valid pairs so far...
# Processed 299 valid pairs so far...
# Processed 300 valid pairs so far...
# Processed 301 valid pairs so far...
# Processed 302 valid pairs so far...
# Processed 303 valid pairs so far...
# Processed 304 valid pairs so far...
# Processed 305 valid pairs so far...
# Processed 306 valid pairs so far...
# Processed 307 valid pairs so far...
# Processed 308 valid pairs so far...
# Processed 309 valid pairs so far...
# Processed 310 valid pairs so far...
# Processed 311 valid pairs so far...
# Processed 312 valid pairs so far...
# Processed 313 valid pairs so far...
# Processed 314 valid pairs so far...
# Processed 315 valid pairs so far...
# Processed 316 valid pairs so far...
# Processed 317 valid pairs so far...
# Processed 318 valid pairs so far...
# Processed 319 valid pairs so far...
# Processed 320 valid pairs so far...
# Processed 321 valid pairs so far...
# Processed 322 valid pairs so far...
# Processed 323 valid pairs so far...
# Processed 324 valid pairs so far...
# Processed 325 valid pairs so far...
# Processed 326 valid pairs so far...
# Processed 327 valid pairs so far...
# Processed 328 valid pairs so far...
# Processed 329 valid pairs so far...
# Processed 330 valid pairs so far...
# Processed 331 valid pairs so far...
# Processed 332 valid pairs so far...
# Processed 333 valid pairs so far...
# Processed 334 valid pairs so far...
# Processed 335 valid pairs so far...
# Processed 336 valid pairs so far...
# Processed 337 valid pairs so far...
# Processed 338 valid pairs so far...
# Processed 339 valid pairs so far...
# Processed 340 valid pairs so far...
# Processed 341 valid pairs so far...
# Processed 342 valid pairs so far...
# Processed 343 valid pairs so far...
# Processed 344 valid pairs so far...
# Processed 345 valid pairs so far...
# Processed 346 valid pairs so far...
# Processed 347 valid pairs so far...
# Processed 348 valid pairs so far...
# Processed 349 valid pairs so far...
# Processed 350 valid pairs so far...
# Processed 351 valid pairs so far...
# Processed 352 valid pairs so far...
# Processed 353 valid pairs so far...
# Processed 354 valid pairs so far...
# Processed 355 valid pairs so far...
# Processed 356 valid pairs so far...
# Processed 357 valid pairs so far...
# Processed 358 valid pairs so far...
# Processed 359 valid pairs so far...
# Processed 360 valid pairs so far...
# Processed 361 valid pairs so far...
# Processed 362 valid pairs so far...
# Processed 363 valid pairs so far...
# Processed 364 valid pairs so far...
# Processed 365 valid pairs so far...
# Processed 366 valid pairs so far...
# Processed 367 valid pairs so far...
# Processed 368 valid pairs so far...
# Processed 369 valid pairs so far...
# Processed 370 valid pairs so far...
# Processed 371 valid pairs so far...
# Processed 372 valid pairs so far...
# Processed 373 valid pairs so far...
# Processed 374 valid pairs so far...
# Processed 375 valid pairs so far...
# Processed 376 valid pairs so far...
# Processed 377 valid pairs so far...
# Processed 378 valid pairs so far...
# Processed 379 valid pairs so far...
# Processed 380 valid pairs so far...
# Processed 381 valid pairs so far...
# Processed 382 valid pairs so far...
# Processed 383 valid pairs so far...
# Processed 384 valid pairs so far...
# Processed 385 valid pairs so far...
# Processed 386 valid pairs so far...
# Processed 387 valid pairs so far...
# Processed 388 valid pairs so far...
# Processed 389 valid pairs so far...
# Processed 390 valid pairs so far...
# Processed 391 valid pairs so far...
# Processed 392 valid pairs so far...
# Processed 393 valid pairs so far...
# Processed 394 valid pairs so far...
# Processed 395 valid pairs so far...
# Processed 396 valid pairs so far...
# Processed 397 valid pairs so far...
# Processed 398 valid pairs so far...
# Processed 399 valid pairs so far...
# Processed 400 valid pairs so far...
# Processed 401 valid pairs so far...
# Processed 402 valid pairs so far...
# Processed 403 valid pairs so far...
# Processed 404 valid pairs so far...
# Processed 405 valid pairs so far...
# Processed 406 valid pairs so far...
# Processed 407 valid pairs so far...
# Processed 408 valid pairs so far...
# Processed 409 valid pairs so far...
# Processed 410 valid pairs so far...
# Processed 411 valid pairs so far...
# Processed 412 valid pairs so far...
# Processed 413 valid pairs so far...
# Processed 414 valid pairs so far...
# Processed 415 valid pairs so far...
# Processed 416 valid pairs so far...
# Processed 417 valid pairs so far...
# Processed 418 valid pairs so far...
# Processed 419 valid pairs so far...
# Processed 420 valid pairs so far...
# Processed 421 valid pairs so far...
# Processed 422 valid pairs so far...
# Processed 423 valid pairs so far...
# Processed 424 valid pairs so far...
# Processed 425 valid pairs so far...
# Processed 426 valid pairs so far...
# Processed 427 valid pairs so far...
# Processed 428 valid pairs so far...
# Processed 429 valid pairs so far...
# Processed 430 valid pairs so far...
# Processed 431 valid pairs so far...
# Processed 432 valid pairs so far...
# Processed 433 valid pairs so far...
# Processed 434 valid pairs so far...
# Processed 435 valid pairs so far...
# Processed 436 valid pairs so far...
# Processed 437 valid pairs so far...
# Processed 438 valid pairs so far...
# Processed 439 valid pairs so far...
# Processed 440 valid pairs so far...
# Processed 441 valid pairs so far...
# Processed 442 valid pairs so far...
# Processed 443 valid pairs so far...
# Processed 444 valid pairs so far...
# Processed 445 valid pairs so far...
# Processed 446 valid pairs so far...
# Processed 447 valid pairs so far...
# Processed 448 valid pairs so far...
# Processed 449 valid pairs so far...
# Processed 450 valid pairs so far...
# Processed 451 valid pairs so far...
# Processed 452 valid pairs so far...
# Processed 453 valid pairs so far...
# Processed 454 valid pairs so far...
# Processed 455 valid pairs so far...
# Processed 456 valid pairs so far...
# Processed 457 valid pairs so far...
# Processed 458 valid pairs so far...
# Processed 459 valid pairs so far...
# Processed 460 valid pairs so far...
# Processed 461 valid pairs so far...
# Processed 462 valid pairs so far...
# Processed 463 valid pairs so far...
# Processed 464 valid pairs so far...
# Processed 465 valid pairs so far...
# Processed 466 valid pairs so far...
# Processed 467 valid pairs so far...
# Processed 468 valid pairs so far...
# Processed 469 valid pairs so far...
# Processed 470 valid pairs so far...
# Processed 471 valid pairs so far...
# Processed 472 valid pairs so far...
# Processed 473 valid pairs so far...
# Processed 474 valid pairs so far...
# Processed 475 valid pairs so far...
# Processed 476 valid pairs so far...
# Processed 477 valid pairs so far...
# Processed 478 valid pairs so far...
# Processed 479 valid pairs so far...
# Processed 480 valid pairs so far...
# Processed 481 valid pairs so far...
# Processed 482 valid pairs so far...
# Processed 483 valid pairs so far...
# Processed 484 valid pairs so far...
# Processed 485 valid pairs so far...
# Processed 486 valid pairs so far...
# Processed 487 valid pairs so far...
# Processed 488 valid pairs so far...
# Processed 489 valid pairs so far...
# Processed 490 valid pairs so far...
# Processed 491 valid pairs so far...
# Processed 492 valid pairs so far...
# Processed 493 valid pairs so far...
# Processed 494 valid pairs so far...
# Processed 495 valid pairs so far...
# Processed 496 valid pairs so far...
# Processed 497 valid pairs so far...
# Processed 498 valid pairs so far...
# Processed 499 valid pairs so far...
# Processed 500 valid pairs so far...
# Processed 501 valid pairs so far...
# Processed 502 valid pairs so far...
# Processed 503 valid pairs so far...
# Processed 504 valid pairs so far...
# Processed 505 valid pairs so far...
# Processed 506 valid pairs so far...
# Processed 507 valid pairs so far...
# Processed 508 valid pairs so far...
# Processed 509 valid pairs so far...
# Processed 510 valid pairs so far...
# Processed 511 valid pairs so far...
# Processed 512 valid pairs so far...
# Processed 513 valid pairs so far...
# Processed 514 valid pairs so far...
# Processed 515 valid pairs so far...
# Processed 516 valid pairs so far...
# Processed 517 valid pairs so far...
# Processed 518 valid pairs so far...
# Processed 519 valid pairs so far...
# Processed 520 valid pairs so far...
# Processed 521 valid pairs so far...
# Processed 522 valid pairs so far...
# Processed 523 valid pairs so far...
# Processed 524 valid pairs so far...
# Processed 525 valid pairs so far...
# Processed 526 valid pairs so far...
# Processed 527 valid pairs so far...
# Processed 528 valid pairs so far...
# Processed 529 valid pairs so far...
# Processed 530 valid pairs so far...
# Processed 531 valid pairs so far...
# Processed 532 valid pairs so far...
# Processed 533 valid pairs so far...
# Processed 534 valid pairs so far...
# Processed 535 valid pairs so far...
# Processed 536 valid pairs so far...
# Processed 537 valid pairs so far...
# Processed 538 valid pairs so far...
# Processed 539 valid pairs so far...
# Processed 540 valid pairs so far...
# Processed 541 valid pairs so far...
# Processed 542 valid pairs so far...
# Processed 543 valid pairs so far...
# Processed 544 valid pairs so far...
# Processed 545 valid pairs so far...
# Processed 546 valid pairs so far...
# Processed 547 valid pairs so far...
# Processed 548 valid pairs so far...
# Processed 549 valid pairs so far...
# Processed 550 valid pairs so far...
# Processed 551 valid pairs so far...
# Processed 552 valid pairs so far...
# Processed 553 valid pairs so far...
# Processed 554 valid pairs so far...
# Processed 555 valid pairs so far...
# Processed 556 valid pairs so far...
# Processed 557 valid pairs so far...
# Processed 558 valid pairs so far...
# Processed 559 valid pairs so far...
# Processed 560 valid pairs so far...
# Processed 561 valid pairs so far...
# Processed 562 valid pairs so far...
# Processed 563 valid pairs so far...
# Processed 564 valid pairs so far...
# Processed 565 valid pairs so far...
# Processed 566 valid pairs so far...
# Processed 567 valid pairs so far...
# Processed 568 valid pairs so far...
# Processed 569 valid pairs so far...
# Processed 570 valid pairs so far...
# Processed 571 valid pairs so far...
# Processed 572 valid pairs so far...
# Processed 573 valid pairs so far...
# Processed 574 valid pairs so far...
# Processed 575 valid pairs so far...
# Processed 576 valid pairs so far...
# Processed 577 valid pairs so far...
# Processed 578 valid pairs so far...
# Processed 579 valid pairs so far...
# Processed 580 valid pairs so far...
# Processed 581 valid pairs so far...
# Processed 582 valid pairs so far...
# Processed 583 valid pairs so far...
# Processed 584 valid pairs so far...
# Processed 585 valid pairs so far...
# Processed 586 valid pairs so far...
# Processed 587 valid pairs so far...
# Processed 588 valid pairs so far...
# Processed 589 valid pairs so far...
# Processed 590 valid pairs so far...
# Processed 591 valid pairs so far...
# Processed 592 valid pairs so far...
# Processed 593 valid pairs so far...
# Processed 594 valid pairs so far...
# Processed 595 valid pairs so far...
# Processed 596 valid pairs so far...
# Processed 597 valid pairs so far...
# Processed 598 valid pairs so far...
# Processed 599 valid pairs so far...
# Processed 600 valid pairs so far...
# Processed 601 valid pairs so far...
# Processed 602 valid pairs so far...
# Processed 603 valid pairs so far...
# Processed 604 valid pairs so far...
# Processed 605 valid pairs so far...
# Processed 606 valid pairs so far...
# Processed 607 valid pairs so far...
# Processed 608 valid pairs so far...
# Processed 609 valid pairs so far...
# Processed 610 valid pairs so far...
# Processed 611 valid pairs so far...
# Processed 612 valid pairs so far...
# Processed 613 valid pairs so far...
# Processed 614 valid pairs so far...
# Processed 615 valid pairs so far...
# Processed 616 valid pairs so far...
# Processed 617 valid pairs so far...
# Processed 618 valid pairs so far...
# Processed 619 valid pairs so far...
# Processed 620 valid pairs so far...
# Processed 621 valid pairs so far...
# Processed 622 valid pairs so far...
# Processed 623 valid pairs so far...
# Processed 624 valid pairs so far...
# Processed 625 valid pairs so far...
# Processed 626 valid pairs so far...
# Processed 627 valid pairs so far...
# Processed 628 valid pairs so far...
# Processed 629 valid pairs so far...
# Processed 630 valid pairs so far...
# Processed 631 valid pairs so far...
# Processed 632 valid pairs so far...
# Processed 633 valid pairs so far...
# Processed 634 valid pairs so far...
# Processed 635 valid pairs so far...
# Processed 636 valid pairs so far...
# Processed 637 valid pairs so far...
# Processed 638 valid pairs so far...
# Processed 639 valid pairs so far...
# Processed 640 valid pairs so far...
# Processed 641 valid pairs so far...
# Processed 642 valid pairs so far...
# Processed 643 valid pairs so far...
# Processed 644 valid pairs so far...
# Processed 645 valid pairs so far...
# Processed 646 valid pairs so far...
# Processed 647 valid pairs so far...
# Processed 648 valid pairs so far...
# Processed 649 valid pairs so far...
# Processed 650 valid pairs so far...
# Processed 651 valid pairs so far...
# Processed 652 valid pairs so far...
# Processed 653 valid pairs so far...
# Processed 654 valid pairs so far...
# Processed 655 valid pairs so far...
# Processed 656 valid pairs so far...
# Processed 657 valid pairs so far...
# Processed 658 valid pairs so far...
# Processed 659 valid pairs so far...
# Processed 660 valid pairs so far...
# Processed 661 valid pairs so far...
# Processed 662 valid pairs so far...
# Processed 663 valid pairs so far...
# Processed 664 valid pairs so far...
# Processed 665 valid pairs so far...
# Processed 666 valid pairs so far...
# Processed 667 valid pairs so far...
# Processed 668 valid pairs so far...
# Processed 669 valid pairs so far...
# Processed 670 valid pairs so far...
# Processed 671 valid pairs so far...
# Processed 672 valid pairs so far...
# Processed 673 valid pairs so far...
# Processed 674 valid pairs so far...
# Processed 675 valid pairs so far...
# Processed 676 valid pairs so far...
# Processed 677 valid pairs so far...
# Processed 678 valid pairs so far...
# Processed 679 valid pairs so far...
# Processed 680 valid pairs so far...
# Processed 681 valid pairs so far...
# Processed 682 valid pairs so far...
# Processed 683 valid pairs so far...
# Processed 684 valid pairs so far...
# Processed 685 valid pairs so far...
# Processed 686 valid pairs so far...
# Processed 687 valid pairs so far...
# Processed 688 valid pairs so far...
# Processed 689 valid pairs so far...
# Processed 690 valid pairs so far...
# Processed 691 valid pairs so far...
# Processed 692 valid pairs so far...
# Processed 693 valid pairs so far...
# Processed 694 valid pairs so far...
# Processed 695 valid pairs so far...
# Processed 696 valid pairs so far...
# Processed 697 valid pairs so far...
# Processed 698 valid pairs so far...
# Processed 699 valid pairs so far...
# Processed 700 valid pairs so far...
# Processed 701 valid pairs so far...
# Processed 702 valid pairs so far...
# Processed 703 valid pairs so far...
# Processed 704 valid pairs so far...
# Processed 705 valid pairs so far...
# Processed 706 valid pairs so far...
# Processed 707 valid pairs so far...
# Processed 708 valid pairs so far...
# Processed 709 valid pairs so far...
# Processed 710 valid pairs so far...
# Processed 711 valid pairs so far...
# Processed 712 valid pairs so far...
# Processed 713 valid pairs so far...
# Processed 714 valid pairs so far...
# Processed 715 valid pairs so far...
# Processed 716 valid pairs so far...
# Processed 717 valid pairs so far...
# Processed 718 valid pairs so far...
# Processed 719 valid pairs so far...
# Processed 720 valid pairs so far...
# Processed 721 valid pairs so far...
# Processed 722 valid pairs so far...
# Processed 723 valid pairs so far...
# Processed 724 valid pairs so far...
# Processed 725 valid pairs so far...
# Processed 726 valid pairs so far...
# Processed 727 valid pairs so far...
# Processed 728 valid pairs so far...
# Processed 729 valid pairs so far...
# Processed 730 valid pairs so far...
# Processed 731 valid pairs so far...
# Processed 732 valid pairs so far...
# Processed 733 valid pairs so far...
# Processed 734 valid pairs so far...
# Processed 735 valid pairs so far...
# Processed 736 valid pairs so far...
# Processed 737 valid pairs so far...
# Processed 738 valid pairs so far...
# Processed 739 valid pairs so far...
# Processed 740 valid pairs so far...
# Processed 741 valid pairs so far...
# Processed 742 valid pairs so far...
# Processed 743 valid pairs so far...
# Processed 744 valid pairs so far...
# Processed 745 valid pairs so far...
# Processed 746 valid pairs so far...
# Processed 747 valid pairs so far...
# Processed 748 valid pairs so far...
# Processed 749 valid pairs so far...
# Processed 750 valid pairs so far...
# Processed 751 valid pairs so far...
# Processed 752 valid pairs so far...
# Processed 753 valid pairs so far...
# Processed 754 valid pairs so far...
# Processed 755 valid pairs so far...
# Processed 756 valid pairs so far...
# Processed 757 valid pairs so far...
# Processed 758 valid pairs so far...
# Processed 759 valid pairs so far...
# Processed 760 valid pairs so far...
# Processed 761 valid pairs so far...
# Processed 762 valid pairs so far...
# Processed 763 valid pairs so far...
# Processed 764 valid pairs so far...
# Processed 765 valid pairs so far...
# Processed 766 valid pairs so far...
# Processed 767 valid pairs so far...
# Processed 768 valid pairs so far...
# Processed 769 valid pairs so far...
# Processed 770 valid pairs so far...
# Processed 771 valid pairs so far...
# Processed 772 valid pairs so far...
# Processed 773 valid pairs so far...
# Processed 774 valid pairs so far...
# Processed 775 valid pairs so far...
# Processed 776 valid pairs so far...
# Processed 777 valid pairs so far...
# Processed 778 valid pairs so far...
# Processed 779 valid pairs so far...
# Processed 780 valid pairs so far...
# Processed 781 valid pairs so far...
# Processed 782 valid pairs so far...
# Processed 783 valid pairs so far...
# Processed 784 valid pairs so far...
# Processed 785 valid pairs so far...
# Processed 786 valid pairs so far...
# Processed 787 valid pairs so far...
# Processed 788 valid pairs so far...
# Processed 789 valid pairs so far...
# Processed 790 valid pairs so far...
# Processed 791 valid pairs so far...
# Processed 792 valid pairs so far...
# Processed 793 valid pairs so far...
# Processed 794 valid pairs so far...
# Processed 795 valid pairs so far...
# Processed 796 valid pairs so far...
# Processed 797 valid pairs so far...
# Processed 798 valid pairs so far...
# Processed 799 valid pairs so far...
# Processed 800 valid pairs so far...
# Processed 801 valid pairs so far...
# Processed 802 valid pairs so far...
# Processed 803 valid pairs so far...
# Processed 804 valid pairs so far...
# Processed 805 valid pairs so far...
# Processed 806 valid pairs so far...
# Processed 807 valid pairs so far...
# Processed 808 valid pairs so far...
# Processed 809 valid pairs so far...
# Processed 810 valid pairs so far...
# Processed 811 valid pairs so far...
# Processed 812 valid pairs so far...
# Processed 813 valid pairs so far...
# Processed 814 valid pairs so far...
# Processed 815 valid pairs so far...
# Processed 816 valid pairs so far...
# Processed 817 valid pairs so far...
# Processed 818 valid pairs so far...
# Processed 819 valid pairs so far...
# Processed 820 valid pairs so far...
# Processed 821 valid pairs so far...
# Processed 822 valid pairs so far...
# Processed 823 valid pairs so far...
# Processed 824 valid pairs so far...
# Processed 825 valid pairs so far...
# Processed 826 valid pairs so far...
# Processed 827 valid pairs so far...
# Processed 828 valid pairs so far...
# Processed 829 valid pairs so far...
# Processed 830 valid pairs so far...
# Processed 831 valid pairs so far...
# Processed 832 valid pairs so far...
# Processed 833 valid pairs so far...
# Processed 834 valid pairs so far...
# Processed 835 valid pairs so far...
# Processed 836 valid pairs so far...
# Processed 837 valid pairs so far...
# Processed 838 valid pairs so far...
# Processed 839 valid pairs so far...
# Processed 840 valid pairs so far...
# Processed 841 valid pairs so far...
# Processed 842 valid pairs so far...
# Processed 843 valid pairs so far...
# Processed 844 valid pairs so far...
# Processed 845 valid pairs so far...
# Processed 846 valid pairs so far...
# Processed 847 valid pairs so far...
# Processed 848 valid pairs so far...
# Processed 849 valid pairs so far...
# Processed 850 valid pairs so far...
# Processed 851 valid pairs so far...
# Processed 852 valid pairs so far...
# Processed 853 valid pairs so far...
# Processed 854 valid pairs so far...
# Processed 855 valid pairs so far...
# Processed 856 valid pairs so far...
# Processed 857 valid pairs so far...
# Processed 858 valid pairs so far...
# Processed 859 valid pairs so far...
# Processed 860 valid pairs so far...
# Processed 861 valid pairs so far...
# Processed 862 valid pairs so far...
# Processed 863 valid pairs so far...
# Processed 864 valid pairs so far...
# Processed 865 valid pairs so far...
# Processed 866 valid pairs so far...
# Processed 867 valid pairs so far...
# Processed 868 valid pairs so far...
# Processed 869 valid pairs so far...
# Processed 870 valid pairs so far...
# Processed 871 valid pairs so far...
# Processed 872 valid pairs so far...
# Processed 873 valid pairs so far...
# Processed 874 valid pairs so far...
# Processed 875 valid pairs so far...
# Processed 876 valid pairs so far...
# Processed 877 valid pairs so far...
# Processed 878 valid pairs so far...
# Processed 879 valid pairs so far...
# Processed 880 valid pairs so far...
# Processed 881 valid pairs so far...
# Processed 882 valid pairs so far...
# Processed 883 valid pairs so far...
# Processed 884 valid pairs so far...
# Processed 885 valid pairs so far...
# Processed 886 valid pairs so far...
# Processed 887 valid pairs so far...
# Processed 888 valid pairs so far...
# Processed 889 valid pairs so far...
# Processed 890 valid pairs so far...
# Processed 891 valid pairs so far...
# Processed 892 valid pairs so far...
# Processed 893 valid pairs so far...
# Processed 894 valid pairs so far...
# Processed 895 valid pairs so far...
# Processed 896 valid pairs so far...
# Processed 897 valid pairs so far...
# Processed 898 valid pairs so far...
# Processed 899 valid pairs so far...
# Processed 900 valid pairs so far...
# Processed 901 valid pairs so far...
# Processed 902 valid pairs so far...
# Processed 903 valid pairs so far...
# Processed 904 valid pairs so far...
# Processed 905 valid pairs so far...
# Processed 906 valid pairs so far...
# Processed 907 valid pairs so far...
# Processed 908 valid pairs so far...
# Processed 909 valid pairs so far...
# Processed 910 valid pairs so far...
# Processed 911 valid pairs so far...
# Processed 912 valid pairs so far...
# Processed 913 valid pairs so far...
# Processed 914 valid pairs so far...
# Processed 915 valid pairs so far...
# Processed 916 valid pairs so far...
# Processed 917 valid pairs so far...
# Processed 918 valid pairs so far...
# Processed 919 valid pairs so far...
# Processed 920 valid pairs so far...
# Processed 921 valid pairs so far...
# Processed 922 valid pairs so far...
# Processed 923 valid pairs so far...
# Processed 924 valid pairs so far...
# Processed 925 valid pairs so far...
# Processed 926 valid pairs so far...
# Processed 927 valid pairs so far...
# Processed 928 valid pairs so far...
# Processed 929 valid pairs so far...
# Processed 930 valid pairs so far...
# Processed 931 valid pairs so far...
# Processed 932 valid pairs so far...
# Processed 933 valid pairs so far...
# Processed 934 valid pairs so far...
# Processed 935 valid pairs so far...
# Processed 936 valid pairs so far...
# Processed 937 valid pairs so far...
# Processed 938 valid pairs so far...
# Processed 939 valid pairs so far...
# Processed 940 valid pairs so far...
# Processed 941 valid pairs so far...
# Processed 942 valid pairs so far...
# Processed 943 valid pairs so far...
# Processed 944 valid pairs so far...
# Processed 945 valid pairs so far...
# Processed 946 valid pairs so far...
# Processed 947 valid pairs so far...
# Processed 948 valid pairs so far...
# Processed 949 valid pairs so far...
# Processed 950 valid pairs so far...
# Processed 951 valid pairs so far...
# Processed 952 valid pairs so far...
# Processed 953 valid pairs so far...
# Processed 954 valid pairs so far...
# Processed 955 valid pairs so far...
# Processed 956 valid pairs so far...
# Processed 957 valid pairs so far...
# Processed 958 valid pairs so far...
# Processed 959 valid pairs so far...
# Processed 960 valid pairs so far...
# Processed 961 valid pairs so far...
# Processed 962 valid pairs so far...
# Processed 963 valid pairs so far...
# Processed 964 valid pairs so far...
# Processed 965 valid pairs so far...
# Processed 966 valid pairs so far...
# Processed 967 valid pairs so far...
# Processed 968 valid pairs so far...
# Processed 969 valid pairs so far...
# Processed 970 valid pairs so far...
# Processed 971 valid pairs so far...
# Processed 972 valid pairs so far...
# Processed 973 valid pairs so far...
# Processed 974 valid pairs so far...
# Processed 975 valid pairs so far...
# Processed 976 valid pairs so far...
# Processed 977 valid pairs so far...
# Processed 978 valid pairs so far...
# Processed 979 valid pairs so far...
# Processed 980 valid pairs so far...
# Processed 981 valid pairs so far...
# Processed 982 valid pairs so far...
# Processed 983 valid pairs so far...
# Processed 984 valid pairs so far...
# Processed 985 valid pairs so far...
# Processed 986 valid pairs so far...
# Processed 987 valid pairs so far...
# Processed 988 valid pairs so far...
# Processed 989 valid pairs so far...
# Processed 990 valid pairs so far...
# Processed 991 valid pairs so far...
# Processed 992 valid pairs so far...
# Processed 993 valid pairs so far...
# Processed 994 valid pairs so far...
# Processed 995 valid pairs so far...
# Processed 996 valid pairs so far...
# Processed 997 valid pairs so far...
# Processed 998 valid pairs so far...
# Processed 999 valid pairs so far...
# Processed 1000 valid pairs so far...
# Processed 1001 valid pairs so far...
# Processed 1002 valid pairs so far...
# Processed 1003 valid pairs so far...
# Processed 1004 valid pairs so far...
# Processed 1973 valid pairs so far...
# Processed 1974 valid pairs so far...
# Processed 1975 valid pairs so far...
# Processed 1976 valid pairs so far...
# Processed 1977 valid pairs so far...
# Processed 1978 valid pairs so far...
# Processed 1979 valid pairs so far...
# Processed 1980 valid pairs so far...
# Processed 1981 valid pairs so far...
# Processed 1982 valid pairs so far...
# Processed 1983 valid pairs so far...
# Processed 1984 valid pairs so far...
# Processed 1985 valid pairs so far...
# Processed 1986 valid pairs so far...
# Processed 1987 valid pairs so far...
# Processed 1988 valid pairs so far...
# Processed 1989 valid pairs so far...
# Processed 1990 valid pairs so far...
# Processed 1991 valid pairs so far...
# Processed 1992 valid pairs so far...
# Processed 1993 valid pairs so far...
# Processed 1994 valid pairs so far...
# Processed 1995 valid pairs so far...
# Processed 1996 valid pairs so far...
# Processed 1997 valid pairs so far...
# Processed 1998 valid pairs so far...
# Processed 1999 valid pairs so far...
# Processed 2000 valid pairs so far...
# Total valid image-mask pairs collected: 2000

# %% [markdown]
# ### PRINTS ALL IMAGES ###
#
# # Function to overlay masks on the image and display the result
# def display_image_with_mask(image_path, mask_path):
#     # Load the image
#     image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
#
#     # Normalize the image to improve visibility
#     image = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX)
#
#     # Load the mask image
#     mask = cv2.imread(mask_path)
#
#     # Check if mask is loaded correctly
#     if mask is None:
#         return
#
#     # Split the mask into individual channels
#     large_bowel_mask = mask[:,:,0]
#     small_bowel_mask = mask[:,:,1]
#     stomach_mask = mask[:,:,2]
#
#     # Check if all three masks contain non-zero values
#     if not (np.any(large_bowel_mask) and np.any(small_bowel_mask) and np.any(stomach_mask)):
#         return
#
#     # Create color masks
#     large_bowel_color = np.zeros_like(mask)
#     small_bowel_color = np.zeros_like(mask)
#     stomach_color = np.zeros_like(mask)
#
#     large_bowel_color[:,:,1] = large_bowel_mask  # Green channel for large bowel
#     small_bowel_color[:,:,2] = small_bowel_mask  # Blue channel for small bowel
#     stomach_color[:,:,0] = stomach_mask  # Red channel for stomach
#
#     # Overlay masks on the original image
#     overlay_large_bowel = cv2.addWeighted(cv2.merge([image, image, image]), 0.7, large_bowel_color, 0.3, 0)
#     overlay_small_bowel = cv2.addWeighted(cv2.merge([image, image, image]), 0.7, small_bowel_color, 0.3, 0)
#     overlay_stomach = cv2.addWeighted(cv2.merge([image, image, image]), 0.7, stomach_color, 0.3, 0)
#
#     # Combine all masks into one overlay
#     combined_masks = cv2.addWeighted(large_bowel_color, 0.3, small_bowel_color, 0.3, 0)
#     combined_masks = cv2.addWeighted(combined_masks, 1, stomach_color, 0.3, 0)
#     overlay_all = cv2.addWeighted(cv2.merge([image, image, image]), 0.7, combined_masks, 0.3, 0)
#
#     # Display the image and masks
#     #plt.figure(figsize=(20, 10))
#
#     #plt.subplot(1, 5, 1)
#     #plt.title('Image')
#     #plt.imshow(image, cmap='gray')
#     #plt.axis('off')
#
#     #plt.subplot(1, 5, 2)
#     #plt.title('Large Bowel Mask Overlay')
#     #plt.imshow(overlay_large_bowel)
#     #plt.axis('off')
#
#     #plt.subplot(1, 5, 3)
#     #plt.title('Small Bowel Mask Overlay')
#     #plt.imshow(overlay_small_bowel)
#     #plt.axis('off')
#
#     #plt.subplot(1, 5, 4)
#     #plt.title('Stomach Mask Overlay')
#     #plt.imshow(overlay_stomach)
#     #plt.axis('off')
#
#     #plt.subplot(1, 5, 5)
#     #plt.title('All Masks Overlay')
#     #plt.imshow(overlay_all)
#     #plt.axis('off')
#
#     #plt.show()
#
# # Iterate over the entries in the dataframe
# for index, row in df.iterrows():
#     # Construct full image path
#     image_relative_path = os.path.relpath(row['image_path'], '/kaggle/input/uw-madison-gi-tract-image-segmentation/train')
#     image_path = os.path.join(images_base_dir, image_relative_path)
#
#     # Construct full mask path
#     mask_relative_path = os.path.relpath(row['mask_path'], '/kaggle/input/uwmgi-mask-dataset/png/uw-madison-gi-tract-image-segmentation/train')
#     mask_path = os.path.join(masks_base_dir, mask_relative_path)
#
#     if os.path.exists(image_path) and os.path.exists(mask_path):
#         display_image_with_mask(image_path, mask_path)

# %%
# Define the normalize_image function
def normalize_image(image):
    # Normalize the image to the range 0-255
    normalized_image = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX)
    # Apply CLAHE
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    equalized_image = clahe.apply(normalized_image)
    return equalized_image

# %% [markdown]
# Feature Extraction

# %%
def extract_features(image):
    rows, cols = image.shape
    # Compute gradients
    grad_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
    grad_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)
    magnitude = cv2.magnitude(grad_x, grad_y)
    angle = cv2.phase(grad_x, grad_y, angleInDegrees=True)
    
    # Add texture features using Gabor filters
    gabor_kernels = [cv2.getGaborKernel((21, 21), 5, theta, 10, 0.5, 0, ktype=cv2.CV_32F) for theta in np.arange(0, np.pi, np.pi / 8)]
    gabor_features = [cv2.filter2D(image, cv2.CV_8UC3, kernel).flatten() for kernel in gabor_kernels]
    
    # Flatten the gradients and combine with Gabor features
    features = np.array([[r, c, image[r, c], magnitude[r, c], angle[r, c]] + [gabor[r * cols + c] for gabor in gabor_features] for r in range(rows) for c in range(cols)])
    return features
    
# Function to extract labels from masks
def extract_labels(mask):
    large_bowel_mask = mask[:,:,0]
    small_bowel_mask = mask[:,:,1]
    stomach_mask = mask[:,:,2]
    
    labels = np.zeros(large_bowel_mask.size, dtype=int)
    labels[large_bowel_mask.flatten() > 0] = 1
    labels[small_bowel_mask.flatten() > 0] = 2
    labels[stomach_mask.flatten() > 0] = 3
    
    return labels

# Filter the dataframe to include only rows where all three masks are non-zero
valid_rows = []
for index, row in df.iterrows():
    # Construct full mask path
    mask_relative_path = os.path.relpath(row['mask_path'], '/kaggle/input/uw-madison-gi-tract-image-segmentation/train')
    mask_path = os.path.join(masks_base_dir, mask_relative_path)
    
    if os.path.exists(mask_path):
        mask = cv2.imread(mask_path)
        if mask is None:
            continue
        
        large_bowel_mask = mask[:,:,0]
        small_bowel_mask = mask[:,:,1]
        stomach_mask = mask[:,:,2]
        
        if np.any(large_bowel_mask) and np.any(small_bowel_mask) and np.any(stomach_mask):
            valid_rows.append(index)

filtered_df = df.loc[valid_rows]
    
# Collect features and labels from a subset of images and masks
features_list = []
labels_list = []
subset_size = 50  # Number of images to use for training

print("Extracting features and labels from images and masks...")
sampled_df = df.sample(subset_size, random_state=30)
for index, row in df.sample(subset_size).iterrows():
    # Construct full image path
    image_relative_path = os.path.relpath(row['image_path'], '/kaggle/input/uw-madison-gi-tract-image-segmentation/train')
    image_path = os.path.join(images_base_dir, image_relative_path)

    # Construct full mask path
    mask_relative_path = os.path.relpath(row['mask_path'], '/kaggle/input/uwmgi-mask-dataset/png/uw-madison-gi-tract-image-segmentation/train')
    mask_path = os.path.join(masks_base_dir, mask_relative_path)

    if os.path.exists(image_path) and os.path.exists(mask_path):
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.imread(mask_path)
        
        if mask is None:
            continue

        # Normalize the image to improve visibility
        image = normalize_image(image)

        # Split the mask into individual channels and check if all three masks contain non-zero values
        large_bowel_mask = mask[:,:,0]
        small_bowel_mask = mask[:,:,1]
        stomach_mask = mask[:,:,2]

        if not (np.any(large_bowel_mask) and np.any(small_bowel_mask) and np.any(stomach_mask)):
            continue
        
        features = extract_features(image)
        labels = extract_labels(mask)
        
        features_list.append(features)
        labels_list.append(labels)

# Combine all features and labels
features = np.vstack(features_list)
labels = np.hstack(labels_list)

print(f"Total features: {features.shape}")
print(f"Total labels: {labels.shape}")
# Out:
# Extracting features and labels from images and masks...
# Total features: (182356, 13)
# Total labels: (182356,)

# %% [markdown]
# Data Splitting

# %%
print("Data splitting...")
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size=0.2, random_state=30)
print("Data split done")
# Out:
# Data splitting...
# Data split done

# %% [markdown]
# Grid Search for the best K value using cross-validation

# %%
print("Finding best K...")
param_grid = {'n_neighbors': list(range(1, 10))}  
knn = KNeighborsClassifier()
grid_search = GridSearchCV(knn, param_grid, cv=3, scoring='accuracy')  # 5-fold cross-validation
grid_search.fit(features_train, labels_train)

# Get the best K value
best_k = grid_search.best_params_['n_neighbors']
best_score = grid_search.best_score_

print(f"Best K value: {best_k}, with Cross-Validation Score: {best_score}")
# Out:
# Finding best K...
# Best K value: 2, with Cross-Validation Score: 0.9729990951715061

# %% [markdown]
# Training

# %%
print("Training K-Nearest Neighbors classifier...")
knn = KNeighborsClassifier(n_neighbors=best_k)
knn.fit(features_train, labels_train)
print("Model training completed")
# Out:
# Training K-Nearest Neighbors classifier...
# Model training completed

# %%
print("Saving images to folder...")
output_folder = '/Users/elizabethnemeti/Desktop/knn_results'
os.makedirs(output_folder, exist_ok=True)
# Out:
# Saving images to folder...

# %%
def predict_and_display(image_path, count, display=False):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    
    # Normalize the image to improve visibility
    image = normalize_image(image)

    # Extract features from the image
    features = extract_features(image)
    
    # Predict segmentation labels
    print(f"Predicting segmentation for {image_path}...")
    predicted_labels = knn.predict(features)
    
    # Reshape predicted labels to match the image dimensions
    segmented_image = predicted_labels.reshape(image.shape)
    
    # Create color mask for visualization
    color_mask = np.zeros((image.shape[0], image.shape[1], 3), dtype=np.uint8)
    color_mask[segmented_image == 1] = [0, 255, 0]  # Green for large bowel
    color_mask[segmented_image == 2] = [0, 0, 255]  # Red for small bowel
    color_mask[segmented_image == 3] = [255, 0, 0]  # Blue for stomach
    
    # Overlay the color mask on the original image
    overlay = cv2.addWeighted(cv2.merge([image, image, image]), 0.7, color_mask, 0.3, 0)

    # Save the image as PNG to the specified folder
    output_file_path = os.path.join(output_folder, f'segmentation_{count}.png')
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.title('Original Image')
    plt.imshow(image, cmap='gray')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title('Segmented Image')
    plt.imshow(overlay)
    plt.axis('off')

    # Add a legend outside the main image area
    legend_elements = [
        Patch(facecolor='red', edgecolor='r', label='Stomach'),
        Patch(facecolor='green', edgecolor='g', label='Large Bowel'),
        Patch(facecolor='blue', edgecolor='b', label='Small Bowel')
    ]
    plt.legend(handles=legend_elements, loc='upper right', bbox_to_anchor=(1.2, 1))
    
    plt.savefig(output_file_path, format='png')

    if display:
        plt.show()
    else:
        plt.close()

    # Clear variables to free memory
    del image, features, predicted_labels, segmented_image, color_mask, overlay
    import gc
    gc.collect()

# %%
# Counter to limit the number of images processed for visualization
count = 0
visualization_limit = 200

print("Predicting and displaying segmentation for new images...")
for index, row in df.iterrows():
    if count >= visualization_limit:
        break

    # Construct full image path
    image_relative_path = os.path.relpath(row['image_path'], '/kaggle/input/uw-madison-gi-tract-image-segmentation/train')
    image_path = os.path.join(images_base_dir, image_relative_path)

    if os.path.exists(image_path):
        predict_and_display(image_path, count, display=(count == 0))
        count += 1

print("Segmentation process completed")
# Out:
# Predicting and displaying segmentation for new images...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0001_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0001_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0001_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0002_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0002_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0002_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0003_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0003_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0003_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0004_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0004_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0004_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0005_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0005_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0005_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0006_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0006_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0006_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0007_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0007_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0007_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0008_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0008_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0008_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0009_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0009_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0009_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0010_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0010_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0010_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0011_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0011_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0011_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0012_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0012_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0012_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0013_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0013_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0013_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0014_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0014_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0014_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0015_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0015_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0015_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0016_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0016_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0016_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0017_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0017_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0017_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0018_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0018_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0018_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0019_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0019_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0019_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0020_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0020_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0020_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0021_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0021_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0021_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0022_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0022_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0022_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0023_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0023_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0023_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0024_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0024_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0024_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0025_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0025_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0025_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0026_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0026_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0026_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0027_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0027_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0027_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0028_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0028_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0028_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0029_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0029_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0029_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0030_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0030_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0030_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0031_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0031_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0031_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0032_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0032_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0032_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0033_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0033_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0033_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0034_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0034_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0034_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0035_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0035_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0035_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0036_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0036_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0036_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0037_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0037_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0037_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0038_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0038_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0038_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0039_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0039_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0039_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0040_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0040_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0040_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0041_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0041_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0041_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0042_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0042_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0042_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0043_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0043_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0043_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0044_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0044_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0044_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0045_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0045_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0045_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0046_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0046_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0046_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0047_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0047_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0047_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0048_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0048_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0048_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0049_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0049_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0049_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0050_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0050_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0050_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0051_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0051_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0051_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0052_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0052_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0052_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0053_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0053_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0053_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0054_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0054_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0054_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0055_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0055_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0055_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0056_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0056_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0056_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0057_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0057_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0057_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0058_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0058_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0058_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0059_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0059_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0059_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0060_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0060_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0060_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0061_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0061_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0061_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0062_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0062_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0062_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0063_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0063_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0063_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0064_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0064_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0064_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0065_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0065_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0065_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0066_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0066_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0066_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0067_266_266_1.50_1.50.png...
# Predicting segmentation for /Users/elizabethnemeti/Desktop/uw-madison-gi-tract-image-segmentation/train/case123/case123_day20/scans/slice_0067_266_266_1.50_1.50.png...
# Segmentation process completed

# %% [markdown]
# Testing

# %%
# Evaluate the Model

# Predict on the test set
labels_pred = knn.predict(features_test)

# Evaluate the model
accuracy = accuracy_score(labels_test, labels_pred)
print(f"Test Accuracy: {accuracy:.2f}")

# Confusion Matrix
conf_matrix = confusion_matrix(labels_test, labels_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification Report
print("Classification Report:\n", classification_report(labels_test, labels_pred))

# %% [markdown]
# Visualize Test Results

# %%
def predict_and_display(image_path, count, display=False):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    
    # Normalize the image to improve visibility
    image = normalize_image(image)

    # Extract features from the image
    features = extract_features(image)
    
    # Predict segmentation labels
    print(f"Predicting segmentation for {image_path}...")
    predicted_labels = knn.predict(features)
    
    # Reshape predicted labels to match the image dimensions
    segmented_image = predicted_labels.reshape(image.shape)
    
    # Create color mask for visualization
    color_mask = np.zeros((image.shape[0], image.shape[1], 3), dtype=np.uint8)
    color_mask[segmented_image == 1] = [0, 255, 0]  # Green for large bowel
    color_mask[segmented_image == 2] = [0, 0, 255]  # Red for small bowel
    color_mask[segmented_image == 3] = [255, 0, 0]  # Blue for stomach
    
    # Overlay the color mask on the original image
    overlay = cv2.addWeighted(cv2.merge([image, image, image]), 0.7, color_mask, 0.3, 0)

    # Save the image as PNG to the specified folder
    output_file_path = os.path.join(output_folder, f'segmentation_{count}.png')
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.title('Original Image')
    plt.imshow(image, cmap='gray')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title('Segmented Image')
    plt.imshow(overlay)
    plt.axis('off')

    # Add a legend outside the main image area
    legend_elements = [
        Patch(facecolor='red', edgecolor='r', label='Stomach'),
        Patch(facecolor='green', edgecolor='g', label='Large Bowel'),
        Patch(facecolor='blue', edgecolor='b', label='Small Bowel')
    ]
    plt.legend(handles=legend_elements, loc='upper right', bbox_to_anchor=(1.2, 1))
    
    plt.savefig(output_file_path, format='png')

    if display:
        plt.show()
    else:
        plt.close()

    # Clear variables to free memory
    del image, features, predicted_labels, segmented_image, color_mask, overlay
    import gc
    gc.collect()

# %% [markdown]
# Predict and display segmentation for test images

# %%
# Select a few test images to visualize their segmentation results
test_indices = np.random.choice(len(features_test), size=5, replace=False)
count = 0
for index in test_indices:
    row = df.iloc[index]
    image_relative_path = os.path.relpath(row['image_path'], '/kaggle/input/uw-madison-gi-tract-image-segmentation/train')
    image_path = os.path.join(images_base_dir, image_relative_path)
    if os.path.exists(image_path):
        predict_and_display(image_path, count, display=True)
        count += 1

print("Segmentation visualization for test images completed")

# %% [markdown]
# Final Visualization and Evaluation Completed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       5 labels_pred = knn.predict(features_test)
#       7 # Evaluate the model
# ----> 8 accuracy = accuracy_score(labels_test, labels_pred)
#       9 print(f"Test Accuracy: {accuracy:.2f}")
#      11 # Confusion Matrix
#
# NameError: name 'accuracy_score' is not defined
